# %% [markdown]
# # Import relevant libaries

# %%
import os                               # Operating system based operations
import time as tim                      # time related operations
import pandas as pd                     # Data Analysis

from pathlib import Path                # Retrieve path of files
from redmail import gmail               # Sending out email via gmail account
from datetime import datetime as dti    # Date time operations.
from tqdm import tqdm as tqdm           # Progess bar on for loops

# %% [markdown]
# # Variable setting

# %%
gmail.username  = os.environ.get("GO_PY_MAIL_USER")                                             # Where the email will be sent fom
gmail.password  = os.environ.get("GO_PY_MAIL_PASS")                                             # Password needed to send via gmail

charity_data    = pd.read_csv("D:\\Coding\\git_projects\\Charity_Scrape\\charity_email_sent_2024-02-08.csv")                 # Download file of charities and their email addresses to contact

charity_emails  = charity_data['email'].to_list()                                               # Convert emails into separate list for iteration
                                                                                             # Convert emails into separate list for iteration

charities       = charity_data['Charity name'].to_list()                                             # convert names into separate list for iteration

cv              = Path("C:\\Users\\lothe\\OneDrive\\CV\\Louis Othen - CV -FEB24.pdf")      # path of cv to upload onto email

# %%
charity_data
# Out:
#     Unnamed: 0                                       Charity name    Income  \
# 0            0                                marlborough college  55465000
# 1            1               aga khan foundation (united kingdom)  57059000
# 2            2                                          millfield  57879000
# 3            3           st aubyn's (woodford green) school trust  59238401
# 4            4                                          actionaid  59635375
# 5            5                     coif charities investment fund  60607000
# 6            6                  alternative futures group limited  61354000
# 7            7                             the wellington college  62581000
# 8            8                                  the brandon trust  63004376
# 9            9                               the donkey sanctuary  63368000
# 10          10                                    we are with you  64517000
# 11          11                           cyngor celfyddydau cymru  65466000
# 12          12                                     macintyre care  65883000
# 13          13                                    charities trust  66029585
# 14          14                                              nacro  66817000
# 15          15      the institution of engineering and technology  67565000
# 16          16                      medecins sans frontieres (uk)  68017311
# 17          17                                    world vision uk  69762595
# 18          18                               bbc children in need  69928692
# 19          19                                  humankind charity  70852215
# 20          20                              plan international uk  72581000
# 21          21  mind (the national association for mental health)  73145000
# 22          22  the keepers and governors of the possessions, ...  74159000
# 23          23  shelter, national campaign for homeless people...  75197000
# 24          24                           the institute of physics  78795000
# 25          25                                           tearfund  79474000
# 26          26  sense, the national deafblind and rubella asso...  82519244
# 27          27                                        jewish care  82706000
# 28          28                         garfield weston foundation  84004000
# 29          29       the royal national institute of blind people  85709000
# 30          30                        education development trust  89070000
# 31          31                                           wateraid  91913000
# 32          32                                    united response  96970000
#
#                                              overview  \
# 0   marlborough college is incorporated by royal c...
# 1   the akf(uk) is an affiliate of the internation...
# 2   the education of children and young people wit...
# 3   the school continues to provide a first-rate, ...
# 4   actionaid uk is part of an international feder...
# 5                                     investment fund
# 6   the charity operates in the north west of engl...
# 7   the charity aims to provide a world-class educ...
# 8   brandon trust exists to improve lifestyles, op...
# 9   to provide rescue homes and treatment for donk...
# 10  provides a range of services for drug and alco...
# 11  the arts council of wales is responsible for d...
# 12  macintyre provides services for adults and chi...
# 13  charities trust works with organisations, indi...
# 14  nacros activities are designed to reduce crime...
# 15  education, policy & awareness activities engag...
# 16  to relieve and promote the relief of sickness ...
# 17  world vision uk is an international christian ...
# 18  the charity?s objects are to further such excl...
# 19  humankind charity specialise in working with p...
# 20  plan international uk is a global childrens ch...
# 21  we provide information and support, campaign t...
# 22  provide education of all-round excellence whic...
# 23  shelter helps millions of people every year st...
# 24  implementation of various projects aimed to pr...
# 25  tearfund is a christian relief and development...
# 26  sense exists so that no one who is deafblind o...
# 27  jewish care cares for people in the jewish com...
# 28  the garfield weston foundation is a family-fou...
# 29  rnib is the uks leading charity offering infor...
# 30  the charity seeks to advance education for the...
# 31  wateraid is an international not-for-profit, d...
# 32  united response is a national charity that wor...
#
#                            what_it_does  \
# 0                 children/young people
# 1                 children/young people
# 2                 children/young people
# 3                 children/young people
# 4                    education/training
# 5                  other defined groups
# 6                    elderly/old people
# 7                 children/young people
# 8              people with disabilities
# 9                 children/young people
# 10                children/young people
# 11        arts/culture/heritage/science
# 12                children/young people
# 13  other charities or voluntary bodies
# 14                children/young people
# 15                children/young people
# 16                   education/training
# 17                   education/training
# 18          general charitable purposes
# 19                children/young people
# 20                   education/training
# 21             people with disabilities
# 22                children/young people
# 23                children/young people
# 24                 other defined groups
# 25  the prevention or relief of poverty
# 26                children/young people
# 27                children/young people
# 28          general charitable purposes
# 29                children/young people
# 30                children/young people
# 31  the prevention or relief of poverty
# 32             people with disabilities
#
#                                      email  \
# 0            sslamb@marlboroughcollege.org
# 1                    front.office@akdn.org
# 2        summerhayes.r@millfieldschool.com
# 3                      bursar@staubyns.com
# 4                       mail@actionaid.org
# 5                    jackie.fox@ccla.co.uk
# 6                       ask@afgroup.org.uk
# 7            sjxc@wellingtoncollege.org.uk
# 8                    info@brandontrust.org
# 9   karen.terrey@thedonkeysanctuary.org.uk
# 10                info@wearewithyou.org.uk
# 11                        comms@arts.wales
# 12           director@macintyrecharity.org
# 13                 info@charitiestrust.org
# 14               rocco.zitola@nacro.org.uk
# 15                   governance@theiet.org
# 16               office-ldn@london.msf.org
# 17                 info@worldvision.org.uk
# 18                        pudsey@bbc.co.uk
# 19            info@humankindcharity.org.uk
# 20          supporterquestions@plan-uk.org
# 21                     contact@mind.org.uk
# 22              bursar@harrowschool.org.uk
# 23                     info@shelter.org.uk
# 24                      governance@iop.org
# 25                      legal@tearfund.org
# 26               fiona.markey@sense.org.uk
# 27                          info@jcare.org
# 28                admin@garfieldweston.org
# 29                    helpline@rnib.org.uk
# 30   corpgov@educationdevelopmenttrust.com
# 31              supportercare@wateraid.org
# 32              info@unitedresponse.org.uk
#
#                                        website
# 0                  www.marlboroughcollege.org
# 1                      https://www.akf.org.uk
# 2                     www.millfieldschool.com
# 3                            www.staubyns.com
# 4                        www.actionaid.org.uk
# 5                              www.ccla.co.uk
# 6                          www.afgroup.org.uk
# 7                www.wellingtoncollege.org.uk
# 8                        www.brandontrust.org
# 9               www.thedonkeysanctuary.org.uk
# 10                    www.wearewithyou.org.uk
# 11                             www.arts.wales
# 12                   www.macintyrecharity.org
# 13                     www.charitiestrust.org
# 14                           www.nacro.org.uk
# 15                             www.theiet.org
# 16                             www.msf.org.uk
# 17                     www.worldvision.org.uk
# 18                       www.bbc.co.uk/pudsey
# 19                www.humankindcharity.org.uk
# 20                            www.plan-uk.org
# 21                            www.mind.org.uk
# 22                    www.harrowschool.org.uk
# 23                         www.shelter.org.uk
# 24                                www.iop.org
# 25                           www.tearfund.org
# 26                           www.sense.org.uk
# 27                         www.jewishcare.org
# 28                     www.garfieldweston.org
# 29                            www.rnib.org.uk
# 30  http://www.educationdevelopmenttrust.com/
# 31                           www.wateraid.org
# 32                  www.unitedresponse.org.uk

# %% [markdown]
# # Initiate the email object and send the email

# %%
for charity,charity_email in tqdm(zip(charities,charity_emails)):
  subject = 'Louis Othen : Looking to offer my data skills for ' + charity #+ " " + dti.now().strftime("%Y-%m-%d")

  body    =   """
              <p>To whom it may concern,</p>
              <br>

              <div>
              My name is Louis Othen, and I apologise for this unexpected email. I came across your details via the Charities Register and am reaching out to offer my services, 
              dedicating a period of time to those committed to making a positive impact for a morally good cause. 
              I am particularly interested in approaching """ + charity + """ where I believe I could be of assistance.
              <div/>

              <br>

              <div>
              I bring over 12 years of experience in the data field, covering analytics, visualization, engineering, science, and machine learning—from on-premise systems to cloud-supplied services and everything in between. 
              Additionally, I have recently completed a master’s degree in Computer Science and Big Data Analytics with distinction to expand my knowledge further. I am hardworking, resourceful, and find fulfilment in work that "helps people who help people". 
              In addition to providing my services, I am keen on imparting knowledge to others within the charity to not only enhance their data function but also foster self-sustainability and growth in this area.
              <div/>

              <br>

              <div>
              I want to clarify that I am initially offering a pro-bono consultation period as a way to contribute to """ + charity + """. Following this pro-bono period, should you find my assistance valuable and wish to continue our collaboration, 
              we can discuss a contractual arrangement for additional support.
              <div/>

              <br>

              <div>
              Thank you for reading and looking forward to our correspondence.
              <div/>

              <br>

              <div>
              Yours Sincerely,
              <div/>
              
              <div>
              Louis Othen
              <div/>

              <br>

              <p>Phone : ###########<p/>
              <p>Email  : lothen123@googlemail.com<p/>
              <p>LinkedIn profile:  https://www.linkedin.com/in/louis-othen/<p/>
              <br>
              """ 

  gmail.send(
              subject     = subject
              ,html       = body
              ,sender     = gmail.username
              ,receivers  = charity_email
              ,attachments= {'louisOthenCV.pdf' : cv}
            ) 
  
  tim.sleep(1)
# Out:
# 33it [01:06,  2.01s/it]
